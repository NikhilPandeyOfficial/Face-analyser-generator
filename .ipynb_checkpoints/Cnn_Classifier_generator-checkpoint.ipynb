# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from keras.preprocessing import image
from keras.layers import *
from keras.utils import np_utils
from keras.models import Sequential
from keras.models import *
import shutil

# %% [markdown]
# ## CNN Model

# %%
def create_model():
    model = Sequential()
    
    model.add(Conv2D(32,(3,3),activation = "relu" , input_shape = (250,250,3))) # ORIGINAL WAS 150, 150
    model.add(Conv2D(56,(3,3), activation = "relu" ))
    model.add(MaxPool2D(2,2))
    model.add(Conv2D(72,(3,3),activation = "relu"))
    model.add(MaxPool2D(2,2))
    model.add(Conv2D(128,(3,3),activation = "relu"))
    model.add(MaxPool2D(2,2))
    model.add(Flatten())
    model.add(Dense(64,activation = "relu"))
    model.add(Dense(4,activation = "softmax"))
    model.summary()
    return model

# %%
create_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 248, 248, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 246, 246, 56)      16184
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 123, 123, 56)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 121, 121, 72)      36360
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 60, 72)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 58, 58, 128)       83072
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 29, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 107648)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                6889536
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 7,026,308
# Trainable params: 7,026,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
def drawimage(image,title="hair color"):
    plt.imshow(image)
    plt.axis("off")
    plt.title(title,fontsize=20)
    plt.show()

# %% [markdown]
# ## Data Preparation

# %%
from keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

# %%
pth = Path("images/")
for file in pth.glob("*"):
    cnt=0
    for img in file.glob("*.jpg"):
        cnt+=1
    print(str(file).split("/")[-1])
    print(cnt)
# Out:
# images\black
# 100
# images\blond
# 100
# images\brown
# 100
# images\gray
# 100

# %%
#dictionardi
digit2label ={0:"black",1:"blond",2:"brown",3:"gray"}

# %% [markdown]
# ### how to create the val file

# %%
os.listdir("images")
# Out:
# ['black', 'blond', 'brown', 'gray']

# %%
if not  os.path.isdir("val_img"):
    os.mkdir("./val_img")

# %%
print(os.listdir("val_img"))
for i in digit2label.items():
    x,y=i
    print(x)
    print(y)
# Out:
# []
# 0
# black
# 1
# blond
# 2
# brown
# 3
# gray

# %%
for c in digit2label.items():
    label,l_name = c
    pth = os.path.join("val_img",l_name)
    print(pth)
    if not os.path.isdir(pth):
        print(pth)
        os.mkdir(pth)
# Out:
# val_img\black
# val_img\black
# val_img\blond
# val_img\blond
# val_img\brown
# val_img\brown
# val_img\gray
# val_img\gray

# %%
print(os.listdir("val_img"))
# Out:
# ['black', 'blond', 'brown', 'gray']

# %%
# change split to 0.9 original was 0.8
split = 0.9
for f in os.listdir("images"):
    p = os.path.join("images/"+f)
    img = os.listdir(p)
    
    split_size = int(split*int(len(img)))
    file_2_mv = img[split_size:]
    print(len(file_2_mv))
    
    for imgfile in file_2_mv:
        src = "images/"+f+"/"+imgfile
        des = "val_img/"+f+"/"+imgfile
        
        print(src)
        print(des)
        
        shutil.move(src,des)
# Out:
# 11
# images/black/black (90).jpg
# val_img/black/black (90).jpg
# images/black/black (91).jpg
# val_img/black/black (91).jpg
# images/black/black (92).jpg
# val_img/black/black (92).jpg
# images/black/black (93).jpg
# val_img/black/black (93).jpg
= ImageDataGenerator(rescale=1./255,validation_split=0.2)

# %%
img_gen_dir = image_gen.flow_from_directory("images/",
        target_size=(250, 250), #original was 150, 150
        batch_size=32,
        class_mode='categorical',
        subset = 'training'                                                              
            )
# Out:
# Found 288 images belonging to 4 classes.

# %%
label ,cnt_label = np.unique(img_gen_dir.labels,return_counts = True)
print(label,cnt_label)
# Out:
# [0 1 2 3] [72 72 72 72]

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  img_gen_dir:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    drawimage(x[1],digit2label[y[1].argmax()])

    cnt+=x.shape[0]
    if cnt > 200:
        break
# Out:
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 0
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 32
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 64
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 96
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 128
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 160
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 192

# %%
validation_generator = image_gen.flow_from_directory(
        'images/',
        target_size=(250, 250), #try with 250, 250 ORIGINAL WAS 150,150
        batch_size=32,
        class_mode='categorical',
        subset = "validation"
)
# Out:
# Found 71 images belonging to 4 classes.

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  validation_generator:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    
    #image draw
    drawimage(x[1],digit2label[y[1].argmax()])
    cnt+=x.shape[0]
    if cnt > 50:
        break
# Out:
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 0
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 32

# %%
print(img_gen_dir.samples)
print(validation_generator.samples)
# Out:
# 288
# 71

# %% [markdown]
# ## Training our Model

# %%
from keras.optimizers import Adam
adam = Adam(lr = 1e-04)

# %%
model = create_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 248, 248, 32)      896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 246, 246, 56)      16184
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 123, 123, 56)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 121, 121, 72)      36360
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 60, 60, 72)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 58, 58, 128)       83072
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 29, 29, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 107648)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                6889536
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 7,026,308
# Trainable params: 7,026,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_model = create_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 248, 248, 32)      896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 246, 246, 56)      16184
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 123, 123, 56)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 121, 121, 72)      36360
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 60, 60, 72)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 58, 58, 128)       83072
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 29, 29, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 107648)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                6889536
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 7,026,308
# Trainable params: 7,026,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_model.compile(optimizer=adam ,loss = "categorical_crossentropy",metrics=["accuracy"])

# %%
batchsize = 32
n_epoch = 20

# %%
hist = class_model.fit_generator(img_gen_dir
                                ,steps_per_epoch=img_gen_dir.samples//batchsize,
                                epochs=n_epoch,
                                 validation_data=validation_generator,
                                 validation_steps=validation_generator.samples//batchsize
                                )
# Out:
# WARNING:tensorflow:From <ipython-input-27-fcdf62cee59b>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 9/9 [==============================] - 72s 8s/step - loss: 1.3729 - accuracy: 0.2847 - val_loss: 1.3049 - val_accuracy: 0.3281
# Epoch 2/20
# 9/9 [==============================] - 62s 7s/step - loss: 1.2630 - accuracy: 0.4410 - val_loss: 1.1867 - val_accuracy: 0.4531
# Epoch 3/20
# 9/9 [==============================] - 63s 7s/step - loss: 1.0918 - accuracy: 0.5799 - val_loss: 0.9667 - val_accuracy: 0.7031
# Epoch 4/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.8591 - accuracy: 0.7257 - val_loss: 0.8060 - val_accuracy: 0.6094
# Epoch 5/20
# 9/9 [==============================] - 63s 7s/step - loss: 0.7245 - accuracy: 0.6632 - val_loss: 0.7030 - val_accuracy: 0.6406
# Epoch 6/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.5860 - accuracy: 0.7917 - val_loss: 0.6955 - val_accuracy: 0.7031
# Epoch 7/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.6024 - accuracy: 0.7361 - val_loss: 0.6600 - val_accuracy: 0.7031
# Epoch 8/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.4963 - accuracy: 0.7951 - val_loss: 0.7526 - val_accuracy: 0.6562
# Epoch 9/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.5142 - accuracy: 0.7778 - val_loss: 0.4927 - val_accuracy: 0.7656
# Epoch 10/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.4082 - accuracy: 0.8299 - val_loss: 0.4474 - val_accuracy: 0.7969
# Epoch 11/20
# 9/9 [==============================] - 66s 7s/step - loss: 0.3697 - accuracy: 0.8438 - val_loss: 0.4698 - val_accuracy: 0.7969
# Epoch 12/20
# 9/9 [==============================] - 64s 7s/step - loss: 0.3392 - accuracy: 0.8542 - val_loss: 0.4431 - val_accuracy: 0.7969
# Epoch 13/20
# 9/9 [==============================] - 63s 7s/step - loss: 0.3229 - accuracy: 0.8542 - val_loss: 0.4267 - val_accuracy: 0.7969
# Epoch 14/20
# 9/9 [==============================] - 64s 7s/step - loss: 0.3335 - accuracy: 0.8438 - val_loss: 0.4097 - val_accuracy: 0.7812
# Epoch 15/20
# 9/9 [==============================] - 63s 7s/step - loss: 0.3151 - accuracy: 0.8507 - val_loss: 0.5232 - val_accuracy: 0.7500
# Epoch 16/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.3134 - accuracy: 0.8438 - val_loss: 0.4137 - val_accuracy: 0.8281
# Epoch 17/20
# 9/9 [==============================] - 62s 7s/step - loss: 0.3099 - accuracy: 0.8576 - val_loss: 0.4316 - val_accuracy: 0.7969
# Epoch 18/20
# 9/9 [==============================] - 65s 7s/step - loss: 0.2502 - accuracy: 0.9167 - val_loss: 0.4812 - val_accuracy: 0.7812
# Epoch 19/20
# 9/9 [==============================] - 64s 7s/step - loss: 0.2253 - accuracy: 0.9236 - val_loss: 0.4185 - val_accuracy: 0.8281
# Epoch 20/20
# 9/9 [==============================] - 63s 7s/step - loss: 0.2305 - accuracy: 0.8889 - val_loss: 0.4037 - val_accuracy: 0.7969

# %% [markdown]
# ## Graph Plot

# %%
plt.plot(hist.history["accuracy"],label="Training accuracy")
plt.plot(hist.history["val_accuracy"],label="Test acc")
plt.legend()

# %%
plt.plot(hist.history["loss"],label="Training loss")
plt.plot(hist.history["val_loss"],label="Test loss")
plt.legend()

# %% [markdown]
# ## Prediction

# %%
pred = class_model.predict(x)
pred[1]
# Out:
# array([4.4761046e-06, 9.9837983e-01, 1.5707085e-03, 4.5039913e-05],
#       dtype=float32)

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  validation_generator:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    pred = class_model.predict(x)
    #image draw
    drawimage(x[1],digit2label[pred[1].argmax()])
    cnt+=1
    if cnt > 20:
        break
# Out:
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 0
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 1
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 2
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 3
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 4
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 5
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 6
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 7
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 8
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 9
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 10
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 11
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 12
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 13
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 14
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 15
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 16
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 17
# ************************************************************
# (7, 250, 250, 3)
# (7, 4)
# 18
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 19
# ************************************************************
# (32, 250, 250, 3)
# (32, 4)
# 20
