# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from keras.preprocessing import image
from keras.layers import *
from keras.utils import np_utils
from keras.models import Sequential
from keras.models import *
import shutil

# %%
def create_model():
    model = Sequential()
    
    model.add(Conv2D(32,(3,3),activation = "relu" , input_shape = (300,300,3)))
    model.add(Conv2D(56,(3,3), activation = "relu" ))
    model.add(MaxPool2D(2,2))
    model.add(Conv2D(72,(3,3),activation = "relu"))
    model.add(MaxPool2D(2,2))
    model.add(Conv2D(128,(3,3),activation = "relu"))
    model.add(MaxPool2D(2,2))
    model.add(Flatten())
    model.add(Dense(64,activation = "relu"))
    model.add(Dense(3,activation = "softmax"))
    model.summary()
    return model

# %%
create_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 146, 146, 56)      16184
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 73, 73, 56)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 71, 71, 72)        36360
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 35, 35, 72)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 33, 33, 128)       83072
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2097216
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,233,923
# Trainable params: 2,233,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
def drawimage(image,title="eye_color"):
    plt.imshow(image)
    plt.axis("off")
    plt.title(title,fontsize=20)
    plt.show()

# %% [markdown]
# ## Data Preparation

# %%
from keras.preprocessing.image import ImageDataGenerator
from pathlib import Path

# %%
pth = Path("images/")
for file in pth.glob("*"):
    cnt=0
    for img in file.glob("*.jpg"):
        cnt+=1
    print(str(file).split("/")[-1])
    print(cnt)
# Out:
# images\blue
# 1000
# images\brown
# 1000
# images\green
# 1000

# %%
#dictionardi
digit2label ={0:"blue",1:"brown",2:"green"}

# %% [markdown]
# ### how to create val file

# %%
os.listdir("images")
# Out:
# ['blue', 'brown', 'green']

# %%
if not  os.path.isdir("val_img"):
    os.mkdir("./val_img")

# %%
print(os.listdir("val_img"))
for i in digit2label.items():
    x,y=i
    print(x)
    print(y)
# Out:
# ['blue', 'brown', 'green']
# 0
# blue
# 1
# brown
# 2
# green

# %%
for c in digit2label.items():
    label,l_name = c
    pth = os.path.join("val_img",l_name)
    print(pth)
    if not os.path.isdir(pth):
        print(pth)
        os.mkdir(pth)
# Out:
# val_img\blue
# val_img\brown
# val_img\green

# %%
print(os.listdir("val_img"))
# Out:
# ['blue', 'brown', 'green']

# %%
split = 0.9
for f in os.listdir("images"):
    p = os.path.join("images/"+f)
    img = os.listdir(p)
    
    split_size = int(split*int(len(img)))
    file_2_mv = img[split_size:]
    print(len(file_2_mv))
    
    for imgfile in file_2_mv:
        src = "images/"+f+"/"+imgfile
        des = "val_img/"+f+"/"+imgfile
        
        print(src)
        print(des)
        
        shutil.move(src,des)
# Out:
# 100
# images/blue/R92685.jpg
# val_img/blue/R92685.jpg
# images/blue/R92686.jpg
# val_img/blue/R92686.jpg
# images/blue/R92687.jpg
# val_img/blue/R92687.jpg
# images/blue/R92711.jpg
# val_img/blue/R92711.jpg
# images/blue/R92713.jpg
# val_img/blue/R92713.jpg
# images/blue/R92730.jpg
# val_img/blue/R92730.jpg
# images/blue/R92735.jpg
# val_img/blue/R92735.jpg
# images/blue/R92740.jpg
# val_img/blue/R92740.jpg
# images/blue/R92741.jpg
# val_img/blue/R92741.jpg
# images/blue/R92747.jpg
# val_img/green/Y21739.jpg
# images/green/Y21819.jpg
# val_img/green/Y21819.jpg
# images/green/Y21881.jpg
# val_img/green/Y21881.jpg
# images/green/Y21947.jpg
# val_img/green/Y21947.jpg
# images/green/Y21998.jpg
# val_img/green/Y21998.jpg
# images/green/Y22050.jpg
# val_img/green/Y22050.jpg
# images/green/Y22171.jpg
# val_img/green/Y22171.jpg
# images/green/Y22223.jpg
# val_img/green/Y22223.jpg
# images/green/Y22225.jpg
# val_img/green/Y22225.jpg
# images/green/Y22336.jpg
# val_img/green/Y22336.jpg
# images/green/Y22632.jpg
# val_img/green/Y22632.jpg
# images/green/Y22723.jpg
# val_img/green/Y22723.jpg
# images/green/Y22768.jpg
# val_img/green/Y22768.jpg
# images/green/Y22774.jpg
# val_img/green/Y22774.jpg
# images/green/Y22783.jpg
# val_img/green/Y22783.jpg
# images/green/Y22796.jpg
# val_img/green/Y22796.jpg
# images/green/Y22866.jpg
# val_img/green/Y22866.jpg
# images/green/Y22946.jpg
# val_img/green/Y22946.jpg
# images/green/Y23068.jpg
# val_img/green/Y23068.jpg
# images/green/Y23146.jpg
# val_img/green/Y23146.jpg
# images/green/Y23159.jpg
# val_img/green/Y23159.jpg
# images/green/Y23318.jpg
# val_img/green/Y23318.jpg
# images/green/Y23329.jpg
# val_img/green/Y23329.jpg
# images/green/Y23477.jpg
# val_img/green/Y23477.jpg
# images/green/Y23549.jpg
# val_img/green/Y23549.jpg
# images/green/Y23550.jpg
# val_img/green/Y23550.jpg
# images/green/Y23654.jpg
# val_img/green/Y23654.jpg
# images/green/Y23803.jpg
# val_img/green/Y23803.jpg
# images/green/Y23929.jpg
# val_img/green/Y23929.jpg
# images/green/Y24094.jpg
# val_img/green/Y24094.jpg
# images/green/Y24107.jpg
# val_img/green/Y24107.jpg
# images/green/Y24248.jpg
# val_img/green/Y24248.jpg
# images/green/Y24523.jpg
# val_img/green/Y24523.jpg
# images/green/Y24550.jpg
# val_img/green/Y24550.jpg
# images/green/Y24728.jpg
# val_img/green/Y24728.jpg
# images/green/Y25002.jpg
# val_img/green/Y25002.jpg
# images/green/Y25052.jpg
# val_img/green/Y25052.jpg
# images/green/Y25132.jpg
# val_img/green/Y25132.jpg
# images/green/Y25189.jpg
# val_img/green/Y25189.jpg
# images/green/Y25284.jpg
# val_img/green/Y25284.jpg
# images/green/Y25364.jpg
# val_img/green/Y25364.jpg

# %%
len(os.listdir("val_img/green/"))
# Out:
# 100

# %% [markdown]
# ### ImageGenerator

# %%
image_gen = ImageDataGenerator(rescale=1./255,validation_split=0.2)

# %%
img_gen_dir = image_gen.flow_from_directory("images/",
        target_size=(300, 300),
        batch_size=32,
        class_mode='categorical',
        subset = 'training'                                                              
            )
# Out:
# Found 2160 images belonging to 3 classes.

# %%
label ,cnt_label = np.unique(img_gen_dir.labels,return_counts = True)
print(label,cnt_label)
# Out:
# [0 1 2] [720 720 720]

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  img_gen_dir:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    drawimage(x[1],digit2label[y[1].argmax()])

    cnt+=x.shape[0]
    if cnt > 200:
        break
# Out:
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 0
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 32
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 64
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 96
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 128
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 160
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 192

# %%
validation_generator = image_gen.flow_from_directory(
        'images/',
        target_size=(300, 300),
        batch_size=32,
        class_mode='categorical',
        subset = "validation"
)
# Out:
# Found 540 images belonging to 3 classes.

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  validation_generator:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    
    #image draw
    drawimage(x[1],digit2label[y[1].argmax()])
    cnt+=x.shape[0]
    if cnt > 50:
        break
# Out:
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 0
# ************************************************************
# (32, 150, 150, 3)
# (32, 3)
# 32

# %%
print(img_gen_dir.samples)
print(validation_generator.samples)
# Out:
# 2160
# 540

# %% [markdown]
# ## Training Our Model

# %%
from keras.optimizers import Adam
adam = Adam(lr = 1e-04)

# %%
model = create_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 146, 146, 56)      16184
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 73, 73, 56)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 71, 71, 72)        36360
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 35, 35, 72)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 33, 33, 128)       83072
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2097216
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,233,923
# Trainable params: 2,233,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_model = create_model()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 146, 146, 56)      16184
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 73, 73, 56)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 71, 71, 72)        36360
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 35, 35, 72)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 33, 33, 128)       83072
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                2097216
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,233,923
# Trainable params: 2,233,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_model.compile(optimizer=adam ,loss = "categorical_crossentropy",metrics=["accuracy"])

# %%
batchsize = 32
n_epoch = 20

# %%
hist = class_model.fit_generator(img_gen_dir
                                ,steps_per_epoch=img_gen_dir.samples//batchsize,
                                epochs=n_epoch,
                                 validation_data=validation_generator,
                                 validation_steps=validation_generator.samples//batchsize
                                )
# Out:
# WARNING:tensorflow:From <ipython-input-48-fcdf62cee59b>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 54/67 [=======================>......] - ETA: 25s - loss: 1.0465 - accuracy: 0.4463

# %% [markdown]
# ## Graph Plot

# %%
plt.plot(hist.history["accuracy"],label="Training accuracy")
plt.plot(hist.history["val_accuracy"],label="Test accuracy")
plt.legend()

# %%
plt.plot(hist.history["loss"],label="Training loss")
plt.plot(hist.history["val_loss"],label="Test loss")
plt.legend()

# %% [markdown]
# ### Prediction

# %%
pred = class_model.predict(x)
pred[0]
# Out:
# array([6.0844450e-04, 9.6699440e-01, 2.2737691e-02, 9.6594272e-03],
#       dtype=float32)

# %%
#batch size of until it reach the no of image
cnt=0
for x ,y in  validation_generator:
    print("*"*60)
    print(x.shape)#batch size vector
    print(y.shape)#one hot vector
    print(cnt)
    pred = class_model.predict(x)
    #image draw
    drawimage(x[0],digit2label[pred[0].argmax()])
    cnt+=1
    if cnt > 20:
        break
# Out:
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 0
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 1
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 2
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 3
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 4
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 5
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 6
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 7
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 8
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 9
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 10
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 11
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 12
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 13
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 14
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 15
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 16
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 17
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 18
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 19
# ************************************************************
# (32, 150, 150, 3)
# (32, 4)
# 20
